# %%
# !pwd
# Out:
# /afs/ihep.ac.cn/users/k/korpachev

# %%
# !ls
# Out:
#  CEPCNoteCover.pdf
#  CEPCSW-master.zip
# 'Generated Sample Stauts for CEPC Simulation Studies.pdf'
#  MyProcessor
#  MyProcessor_cyberpfo
#  MyProcessor_mc
#  MyProcessor_old
#  TotalInvJets
#  TotalInvJets_old
#  Untitled.ipynb
#  cepc_sample_note_latest.pdf
#  help.txt
#  mmmy_CEPCV4_simu_reco_Arbor.py
#  my_CEPCV4_simu_reco_Arbor.py
#  myprocessor.py
#  private
#  public
#  viewer_cepc

# %%
# !ls /cefs/higgs/korpachev
# Out:
# CEPCSW-master
# CEPCSW-master.zip
# E250-TDR_ws.Pqqh_zz_4n.Gwhizard-1_95.eL.pR.I108079.001.stdhep
# aaa
# backup
# help.txt
# hep_condor
# hz_WW_4j_240.slcio
# old
# test_for_students

# %%
import uproot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import uproot
#
# ModuleNotFoundError: No module named 'uproot'

# %%
# !which python
# Out:
# /usr/bin/python

# %%
# !ls /cvmfs/slurm.ihep.ac.cn/centos7.9/anaconda3/bin/python
# Out:
# /cvmfs/slurm.ihep.ac.cn/centos7.9/anaconda3/bin/python

# %%
import sys
sys.path.append('/home/cc/hanx/my_python_packages')

# %%
# !python --version
# Out:
# Python 3.9.18

# %%
import uproot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import uproot
#
# ModuleNotFoundError: No module named 'uproot'
